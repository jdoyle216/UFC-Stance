# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations
# %matplotlib inline

# %%
df = pd.read_csv('/users/jdoyle216/downloads/ufc-master.csv')
df.head()
# Out:
#         R_fighter         B_fighter  R_odds  B_odds       R_ev   B_ev  \
# 0   Edson Barboza     Giga Chikadze    -125     105  80.000000  105.0
# 1    Bryan Battle    Gilbert Urbina    -200     170  50.000000  170.0
# 2   Ricky Turcios    Brady Hiestand    -145     125  68.965517  125.0
# 3       Kevin Lee  Daniel Rodriguez    -145     125  68.965517  125.0
# 4  Andre Petroski  Micheal Gillmore    -550     400  18.181818  400.0
#
#          date                location country Winner  ...    finish_details  \
# 0  2021-08-28  Las Vegas, Nevada, USA     USA   Blue  ...             Punch
# 1  2021-08-28  Las Vegas, Nevada, USA     USA    Red  ...  Rear Naked Choke
# 2  2021-08-28  Las Vegas, Nevada, USA     USA    Red  ...               NaN
# 3  2021-08-28  Las Vegas, Nevada, USA     USA   Blue  ...               NaN
# 4  2021-08-28  Las Vegas, Nevada, USA     USA    Red  ...            Elbows
#
#   finish_round finish_round_time  total_fight_time_secs  r_dec_odds  \
# ...

# %%
list(df.columns)
# Out:
# ['R_fighter',
#  'B_fighter',
#  'R_odds',
#  'B_odds',
#  'R_ev',
#  'B_ev',
#  'date',
#  'location',
#  'country',
#  'Winner',
#  'title_bout',
#  'weight_class',
#  'gender',
#  'no_of_rounds',
#  'B_current_lose_streak',
#  'B_current_win_streak',
#  'B_draw',
#  'B_avg_SIG_STR_landed',
#  'B_avg_SIG_STR_pct',
#  'B_avg_SUB_ATT',
#  'B_avg_TD_landed',
#  'B_avg_TD_pct',
#  'B_longest_win_streak',
#  'B_losses',
#  'B_total_rounds_fought',
#  'B_total_title_bouts',
#  'B_win_by_Decision_Majority',
#  'B_win_by_Decision_Split',
#  'B_win_by_Decision_Unanimous',
#  'B_win_by_KO/TKO',
#  'B_win_by_Submission',
#  'B_win_by_TKO_Doctor_Stoppage',
#  'B_wins',
#  'B_Stance',
#  'B_Height_cms',
#  'B_Reach_cms',
#  'B_Weight_lbs',
#  'R_current_lose_streak',
#  'R_current_win_streak',
#  'R_draw',
#  'R_avg_SIG_STR_landed',
#  'R_avg_SIG_STR_pct',
#  'R_avg_SUB_ATT',
#  'R_avg_TD_landed',
#  'R_avg_TD_pct',
#  'R_longest_win_streak',
#  'R_losses',
#  'R_total_rounds_fought',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4850 entries, 0 to 4849
# Columns: 119 entries, R_fighter to b_ko_odds
# dtypes: bool(1), float64(57), int64(47), object(14)
# memory usage: 4.4+ MB

# %%
df.describe()
# Out:
#            R_odds       B_odds         R_ev         B_ev  no_of_rounds  \
# count  4850.00000  4850.000000  4850.000000  4850.000000   4850.000000
# mean   -117.48866    66.079588    94.788651   167.072018      3.181649
# std     268.20965   247.545580    82.792599   136.711756      0.570999
# min   -1700.00000 -1200.000000     5.882353     8.333333      3.000000
# 25%    -255.00000  -145.000000    39.215686    68.965517      3.000000
# 50%    -150.00000   130.000000    66.666667   130.000000      3.000000
# 75%     125.75000   220.000000   125.750000   220.000000      3.000000
# max     775.00000  1300.000000   775.000000  1300.000000      5.000000
#
#        B_current_lose_streak  B_current_win_streak       B_draw  \
# count            4850.000000           4850.000000  4850.000000
# mean                0.476701              0.874433     0.010103
# std                 0.768243              1.311036     0.106021
# min                 0.000000              0.000000     0.000000
# ...

# %%
df.isnull().sum(axis = 0).sort_values(ascending=False).head(20)
# Out:
# B_Women's Featherweight_rank    4850
# R_Women's Featherweight_rank    4843
# B_Pound-for-Pound_rank          4816
# B_Women's Flyweight_rank        4809
# R_Women's Flyweight_rank        4794
# B_Women's Strawweight_rank      4789
# B_Women's Bantamweight_rank     4773
# B_Bantamweight_rank             4766
# B_Lightweight_rank              4763
# B_Welterweight_rank             4761
# B_Featherweight_rank            4761
# B_Light Heavyweight_rank        4759
# B_Flyweight_rank                4755
# B_Middleweight_rank             4749
# R_Women's Strawweight_rank      4746
# B_Heavyweight_rank              4743
# R_Women's Bantamweight_rank     4733
# R_Featherweight_rank            4718
# R_Middleweight_rank             4717
# R_Bantamweight_rank             4714
# dtype: int64

# %%
df.loc[:, df.isna().any()]
# Out:
#       B_avg_SIG_STR_landed  B_avg_SIG_STR_pct  B_avg_SUB_ATT  B_avg_TD_landed  \
# 0                 3.760000               0.45       0.300000         0.330000
# 1                 6.210000               0.59       0.000000         4.140000
# 2                 4.400000               0.49       0.000000         6.000000
# 3                 8.060000               0.50       0.200000         0.840000
# 4                 2.350000               0.59       0.000000         0.000000
# ...                    ...                ...            ...              ...
# 4845                   NaN                NaN            NaN              NaN
# 4846                   NaN                NaN            NaN              NaN
# 4847              8.000000               0.34       1.000000         1.000000
# 4848                   NaN                NaN            NaN              NaN
# 4849             31.666667               0.46       0.666667         1.666667
#
# ...

# %%
df.info()
df.B_Stance.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4850 entries, 0 to 4849
# Columns: 119 entries, R_fighter to b_ko_odds
# dtypes: bool(1), float64(57), int64(47), object(14)
# memory usage: 4.4+ MB
# Orthodox       3645
# Southpaw        972
# Switch          229
# Switch            1
# Open Stance       1
# Name: B_Stance, dtype: int64

# %%
Ortho = df['B_Stance'][df['B_Stance']=='Orthodox'].count()
Southpaw = df['B_Stance'][df['B_Stance']=='Southpaw'].count()
Switch = df['B_Stance'][df['B_Stance']=='Switch'].count()

# %%
Orthp = Ortho/4849
Southpawp = Southpaw/4849
Switchp1 = (Switch+1)/4849

# %%
print("The percentage of Orthodox fighters is {}:".format("%.2f" % Orthp))
print("The percentage of Southpaw fighters is {}:".format("%.2f" %Southpawp))
print("The percentage of Switch fighters is {}:".format("%.2f" %Switchp1))
# Out:
# The percent of Orthodox fighters is 0.75:
# The percent of Southpaw fighters is 0.20:
# The percent of Switch fighters is 0.05:

# %%
df.groupby(['B_Stance','R_Stance']).size().reset_index().rename(columns={0:'count'}).sort_values(by=['count'],ascending=False)
# Out:
#        B_Stance     R_Stance  count
# 2      Orthodox     Orthodox   2790
# 3      Orthodox     Southpaw    720
# 6      Southpaw     Orthodox    715
# 7      Southpaw     Southpaw    212
# 9        Switch     Orthodox    174
# 4      Orthodox       Switch    132
# 10       Switch     Southpaw     47
# 8      Southpaw       Switch     44
# 11       Switch       Switch      8
# 1      Orthodox  Open Stance      3
# 0   Open Stance     Southpaw      1
# 5      Southpaw  Open Stance      1
# 12      Switch        Switch      1

# %%
df.groupby(['B_Stance','R_Stance']).size().reset_index().rename(columns={0:'count'}).sort_values(by=['count'],ascending=False)
# Out:
#        B_Stance     R_Stance  count
# 2      Orthodox     Orthodox   2790
# 3      Orthodox     Southpaw    720
# 6      Southpaw     Orthodox    715
# 7      Southpaw     Southpaw    212
# 9        Switch     Orthodox    174
# 4      Orthodox       Switch    132
# 10       Switch     Southpaw     47
# 8      Southpaw       Switch     44
# 11       Switch       Switch      8
# 1      Orthodox  Open Stance      3
# 0   Open Stance     Southpaw      1
# 5      Southpaw  Open Stance      1
# 12      Switch        Switch      1

# %%
df[df['B_Stance'] == 'Open Stance']
# Out:
#            R_fighter            B_fighter  R_odds  B_odds   R_ev       B_ev  \
# 4525  Mike Massenzio  Krzysztof Soszynski     265    -325  265.0  30.769231
#
#            date                             location  country Winner  ...  \
# 4525  6/11/2011  Vancouver, British Columbia, Canada   Canada   Blue  ...
#
#       finish_details finish_round finish_round_time  total_fight_time_secs  \
# 4525             NaN          3.0              5:00                  900.0
#
#       r_dec_odds  b_dec_odds  r_sub_odds  b_sub_odds  r_ko_odds  b_ko_odds
# 4525         NaN         NaN         NaN         NaN        NaN        NaN
#
# [1 rows x 119 columns]

# %%
df1 = df[df.R_Stance != 'Open Stance']
df1 = df1[df.B_Stance != 'Open Stance']
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df1
# Out:
#            R_fighter         B_fighter  R_odds  B_odds        R_ev   B_ev  \
# 0      Edson Barboza     Giga Chikadze    -125     105   80.000000  105.0
# 1       Bryan Battle    Gilbert Urbina    -200     170   50.000000  170.0
# 2      Ricky Turcios    Brady Hiestand    -145     125   68.965517  125.0
# 3          Kevin Lee  Daniel Rodriguez    -145     125   68.965517  125.0
# 4     Andre Petroski  Micheal Gillmore    -550     400   18.181818  400.0
# ...              ...               ...     ...     ...         ...    ...
# 4845    Duane Ludwig     Darren Elkins    -155     135   64.516129  135.0
# 4846     John Howard    Daniel Roberts    -210     175   47.619048  175.0
# 4847  Brendan Schaub     Chase Gormley    -260     220   38.461538  220.0
# 4848     Mike Pierce     Julio Paulino    -420     335   23.809524  335.0
# 4849    Eric Schafer       Jason Brilz     140    -160  140.000000   62.5
#
#             date                   location country Winner  ...  \
# ...

# %%
conditions = [
    (df1['R_Stance'] == 'Orthodox') & (df1['B_Stance'] == 'Orthodox'),
    (df1['R_Stance'] == 'Orthodox') & (df1['B_Stance'] == 'Southpaw'),
    (df1['R_Stance'] == 'Southpaw') & (df1['B_Stance'] == 'Southpaw'),
    (df1['R_Stance'] == 'Southpaw') & (df1['B_Stance'] == 'Orthodox'),
    (df1['R_Stance'] == 'Orthodox') & (df1['B_Stance'] == 'Switch'),
    (df1['R_Stance'] == 'Switch') & (df1['B_Stance'] == 'Orthodox'),
    (df1['R_Stance'] == 'Southpaw') & (df1['B_Stance'] == 'Switch'),
    (df1['R_Stance'] == 'Switch') & (df1['B_Stance'] == 'Southpaw'),
    (df1['R_Stance'] == 'Switch') & (df1['B_Stance'] == 'Switch')
    
    ]

# create a list of the values we want to assign for each condition
values = ['Orth_vs_Orth','Ortho_vs_Southpaw','Southpaw_vs_Southpaw','Ortho_vs_Southpaw','Ortho_vs_Switch','Ortho_vs_Switch','Southpaw_vs_Switch','Southpaw_vs_Switch','Switch_vs_Switch']

# create a new column and use np.select to assign values to it using our lists as arguments
df1['Stances'] = np.select(conditions, values)

# display updated DataFrame
df1.head()
# Out:
#         R_fighter         B_fighter  R_odds  B_odds       R_ev   B_ev  \
# 0   Edson Barboza     Giga Chikadze    -125     105  80.000000  105.0
# 1    Bryan Battle    Gilbert Urbina    -200     170  50.000000  170.0
# 2   Ricky Turcios    Brady Hiestand    -145     125  68.965517  125.0
# 3       Kevin Lee  Daniel Rodriguez    -145     125  68.965517  125.0
# 4  Andre Petroski  Micheal Gillmore    -550     400  18.181818  400.0
#
#          date                location country Winner  ...  finish_round  \
# 0  2021-08-28  Las Vegas, Nevada, USA     USA   Blue  ...           3.0
# 1  2021-08-28  Las Vegas, Nevada, USA     USA    Red  ...           2.0
# 2  2021-08-28  Las Vegas, Nevada, USA     USA    Red  ...           3.0
# 3  2021-08-28  Las Vegas, Nevada, USA     USA   Blue  ...           3.0
# 4  2021-08-28  Las Vegas, Nevada, USA     USA    Red  ...           3.0
#
#   finish_round_time total_fight_time_secs  r_dec_odds  b_dec_odds  r_sub_odds  \
# ...

# %%
df1['Stances'].value_counts(normalize=True)
# Out:
# Orth_vs_Orth            0.575851
# Ortho_vs_Southpaw       0.296182
# Ortho_vs_Switch         0.063158
# Southpaw_vs_Southpaw    0.043756
# Southpaw_vs_Switch      0.018782
# Switch_vs_Switch        0.001651
# 0                       0.000619
# Name: Stances, dtype: float64

# %%
df1['Stances'].value_counts()
# Out:
# Orth_vs_Orth            2790
# Ortho_vs_Southpaw       1435
# Ortho_vs_Switch          306
# Southpaw_vs_Southpaw     212
# Southpaw_vs_Switch        91
# Switch_vs_Switch           8
# 0                          3
# Name: Stances, dtype: int64

# %%
df1['StanceWinner'] = np.where(df1['Winner'] == 'Blue', df1['B_Stance'], df1['R_Stance'])
df1['StanceWinner']
# Out:
# 0       Orthodox
# 1       Orthodox
# 2       Orthodox
# 3       Southpaw
# 4         Switch
#           ...
# 4845    Orthodox
# 4846    Orthodox
# 4847    Orthodox
# 4848    Orthodox
# 4849    Orthodox
# Name: StanceWinner, Length: 4845, dtype: object

# %%
df2 = df1.groupby(['Stances','StanceWinner']).agg('size')

# %%
df2.groupby(level=0).apply(lambda x:100 * x / float(x.sum())).reset_index().loc[4:,:]
# Out:
#                  Stances StanceWinner           0
# 4      Ortho_vs_Southpaw     Orthodox   48.501742
# 5      Ortho_vs_Southpaw     Southpaw   51.498258
# 6        Ortho_vs_Switch     Orthodox   48.366013
# 7        Ortho_vs_Switch       Switch   51.633987
# 8   Southpaw_vs_Southpaw     Southpaw  100.000000
# 9     Southpaw_vs_Switch     Southpaw   47.252747
# 10    Southpaw_vs_Switch       Switch   52.747253
# 11      Switch_vs_Switch       Switch  100.000000

# %%
df3 = df1.groupby('Winner').size().reset_index()

# %%
df3['percent'] = (df3[0] / df3[0].sum()) * 100

# %%
df3
# Out:
#   Winner     0    percent
# 0   Blue  2015  41.589267
# 1    Red  2830  58.410733
